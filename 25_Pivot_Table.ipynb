# %% [markdown]
# ## PivotTable.js is a powerful JavaScript library that enables the creation of interactive pivot tables for data analysis and exploration in web applications. It provides a user-friendly interface to visualize and summarize complex datasets, allowing users to interactively manipulate the data to gain valuable insights.

# %%
#https://medium.com/@yashrajeshjadhav/instant-pivot-tables-with-pivottable-js-830993200e94
#https://pypi.org/project/pivottablejs/

# %%
 """https://pivottable.js.org/examples/local.html -----------------------Drop a CSV FILE ON THIS PAGE """
#https://www.youtube.com/watch?v=ZbrRrXiWBKc&t=14s

# %%
from IPython.display import Image
Image("summary.png")

# %% [raw]
# pip install pivottablejs

# %%
import pandas as pd
from pivottablejs import pivot_ui

# Load the dataset into a DataFrame
df = pd.read_csv("mps.csv")

# %%
df.head(2)
# Out:
#    Person ID First name Last name                Party  \
# 0      10001      Diane    Abbott               Labour
# 1      26385       Jack    Abbott  Labour/Co-operative
#
#                         Constituency  \
# 0  Hackney North and Stoke Newington
# 1                            Ipswich
#
#                                                  URI
# 0  https://www.theyworkforyou.com/mp/10001/diane_...
# 1  https://www.theyworkforyou.com/mp/26385/jack_a...

# %%
# Create a pivot table using the pivot_ui function
pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# > * Polling Station Analysis, Voter Distribution by Region, State vs. Candidate (By Party),
# Candidate vs. Votes, Sales Data: Purpose: To analyze which products are performing best in which regions.
# Customer Data:Purpose: To understand purchasing patterns based on gender and country.
# Employee Data: Purpose: To analyze average salary by department and performance rating.
# Survey Data:Purpose: To summarize survey results and group answers by questions and demographics.
# Financial Data:Purpose: To analyze expenditures and revenues by category and account.
# Healthcare Data:Purpose: To examine the number of patients diagnosed with certain conditions and treated by different doctors.
# Inventory Data:Purpose: To see the stock distribution of products across different warehouses.
#
#
#
# >* In summary, drag-and-drop functionality in pivot tables is an excellent way to interactively explore, summarize, and visualize ex- election data, helping you gain insights into voting patterns, candidate performance, and regional trends.

# %%
from IPython.display import Image
Image("elections_data set.png")
